# %%
import os
import utils.experiment
import utils.dirtools
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from config import config_vars

experiment_name = 'impact_of_augmented_dataset_size'

partition = "validation"

total_repetitions = 10

config_vars = utils.dirtools.setup_experiment(config_vars, experiment_name)

config_vars
# Out:
# {'root_directory': 'data1/image-segmentation/BBBC022/unet/',
#  'max_training_images': 0,
#  'create_split_files': False,
#  'training_fraction': 0.5,
#  'validation_fraction': 0.25,
#  'transform_images_to_PNG': True,
#  'pixel_depth': 8,
#  'min_nucleus_size': 25,
#  'boundary_size': 2,
#  'augment_images': False,
#  'elastic_points': 16,
#  'elastic_distortion': 5,
#  'elastic_augmentations': 10,
#  'learning_rate': 0.0001,
#  'epochs': 15,
#  'steps_per_epoch': 500,
#  'batch_size': 10,
#  'val_batch_size': 10,
#  'rescale_labels': True,
#  'crop_size': 256,
#  'cell_min_size': 16,
#  'boundary_boost_factor': 1,
#  'object_dilation': 3,
#  'raw_images_dir': 'data1/image-segmentation/BBBC022/unet/raw_images/',
#  'raw_annotations_dir': 'data1/image-segmentation/BBBC022/unet/raw_annotations/',
#  'path_files_training': 'data1/image-segmentation/BBBC022/unet/training.txt',
#  'path_files_validation': 'data1/image-segmentation/BBBC022/unet/validation.txt',
#  'path_files_test': 'data1/image-segmentation/BBBC022/unet/test.txt',
#  'normalized_images_dir': 'data1/image-segmentation/BBBC022/unet/norm_images/',
#  'boundary_labels_dir': 'data1/image-segmentation/BBBC022/unet/boundary_labels/',
#  'experiment_dir': 'data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/',
#  'probmap_out_dir': 'data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/prob/',
#  'labels_out_dir': 'data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/',
#  'model_file': 'data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/model.hdf5',
#  'csv_log_file': 'data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/log.csv'}

# %%
results = pd.DataFrame(columns=["Samples", "Repeat", "MAP", "Missed", "Merges", "Splits"])
idx = 0

for max_samples in [2, 4, 6, 8, 10, 20, 40, 60, 80, 100]:
    for repetition in range(total_repetitions):
        print("Experiment", idx, "- max_samples:", max_samples, "- repetition:", repetition)
        
        # Modify settings
        config_vars["max_training_images"] = max_samples
        
        # Reconfigure variables and data partitions
        config_vars = utils.dirtools.setup_experiment(config_vars, experiment_name)
        data_partitions = utils.dirtools.read_data_partitions(config_vars)
        
        # Run experiment
        output = utils.experiment.run(config_vars, data_partitions, experiment_name, partition, GPU="2")
        
        # Collect outputs
        record = {
            "Samples": max_samples,
            "Repeat": repetition,
            "MAP": output["MAP"],
            "Missed": output["Missed"].sum(),
            "Merges": output["Merges"],
            "Splits": output["Splits"]
        }
        results.loc[idx] = record
        idx += 1
        
        # Clean up directories
        experiment_dir = config_vars["root_directory"] + "/experiments/" + experiment_name
        if os.path.exists(experiment_dir):
            os.system("rm -Rf " + experiment_dir)
            
        # Save results
        results.to_csv(config_vars["root_directory"] + "/experiments/" + experiment_name + ".csv")
# Out:
# Experiment 0 - max_samples: 2 - repetition: 0
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(x)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:17: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   a = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(a)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:20: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   a = keras.layers.BatchNormalization(**option_dict_bn)(a)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:26: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   b = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(b)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:29: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   b = keras.layers.BatchNormalization(**option_dict_bn)(b)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:34: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:35: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   c = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(c)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:38: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   c = keras.layers.BatchNormalization(**option_dict_bn)(c)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:43: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:44: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(512, (3, 3), activation="relu", padding="same")`
#   d = keras.layers.Convolution2D(512, 3, 3, **option_dict_conv)(d)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:47: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   d = keras.layers.BatchNormalization(**option_dict_bn)(d)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:56: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:57: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:59: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), activation="relu", padding="same")`
#   e = keras.layers.Convolution2D(256, 3, 3, **option_dict_conv)(e)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:60: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   e = keras.layers.BatchNormalization(**option_dict_bn)(e)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:67: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:68: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:70: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), activation="relu", padding="same")`
#   f = keras.layers.Convolution2D(128, 3, 3, **option_dict_conv)(f)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:71: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   f = keras.layers.BatchNormalization(**option_dict_bn)(f)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:78: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:79: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:81: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(64, 3, 3, **option_dict_conv)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:82: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(momentum=0.9)`
#   y = keras.layers.BatchNormalization(**option_dict_bn)(y)
# /home/lanbowen23/Instance/unet4nuclei/unet4nuclei/utils/model_builder.py:91: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(3, (1, 1), activation="relu", padding="same")`
#   y = keras.layers.Convolution2D(3, 1, 1, **option_dict_conv)(y)
# Epoch 1/15
# Training with 2 images.
# 500/500 [==============================] - 159s 318ms/step - loss: 0.1321 - categorical_accuracy: 0.9753 - background_recall: 0.9816 - background_precision: 0.9992 - interior_recall: 0.9189 - interior_precision: 0.9838 - boundary_recall: 0.9688 - boundary_precision: 0.5346 - val_loss: 0.2870 - val_categorical_accuracy: 0.9578 - val_background_recall: 0.9645 - val_background_precision: 0.9987 - val_interior_recall: 0.9462 - val_interior_precision: 0.9729 - val_boundary_recall: 0.8902 - val_boundary_precision: 0.5401
# Epoch 2/15
# 500/500 [==============================] - 155s 309ms/step - loss: 0.0524 - categorical_accuracy: 0.9880 - background_recall: 0.9927 - background_precision: 0.9998 - interior_recall: 0.9459 - interior_precision: 0.9975 - boundary_recall: 0.9835 - boundary_precision: 0.6633 - val_loss: 0.3629 - val_categorical_accuracy: 0.9596 - val_background_recall: 0.9671 - val_background_precision: 0.9981 - val_interior_recall: 0.9533 - val_interior_precision: 0.9505 - val_boundary_recall: 0.8569 - val_boundary_precision: 0.5661
# Epoch 3/15
# 500/500 [==============================] - 155s 310ms/step - loss: 0.0338 - categorical_accuracy: 0.9921 - background_recall: 0.9956 - background_precision: 0.9998 - interior_recall: 0.9616 - interior_precision: 0.9983 - boundary_recall: 0.9866 - boundary_precision: 0.7509 - val_loss: 0.3519 - val_categorical_accuracy: 0.9700 - val_background_recall: 0.9797 - val_background_precision: 0.9974 - val_interior_recall: 0.9563 - val_interior_precision: 0.9700 - val_boundary_recall: 0.8568 - val_boundary_precision: 0.6362
# Epoch 4/15
# 500/500 [==============================] - 155s 309ms/step - loss: 0.0247 - categorical_accuracy: 0.9942 - background_recall: 0.9969 - background_precision: 0.9998 - interior_recall: 0.9709 - interior_precision: 0.9988 - boundary_recall: 0.9890 - boundary_precision: 0.8051 - val_loss: 0.4288 - val_categorical_accuracy: 0.9692 - val_background_recall: 0.9794 - val_background_precision: 0.9970 - val_interior_recall: 0.9570 - val_interior_precision: 0.9551 - val_boundary_recall: 0.8226 - val_boundary_precision: 0.6289
# Epoch 5/15
# 500/500 [==============================] - 154s 309ms/step - loss: 0.0193 - categorical_accuracy: 0.9954 - background_recall: 0.9976 - background_precision: 0.9999 - interior_recall: 0.9769 - interior_precision: 0.9990 - boundary_recall: 0.9911 - boundary_precision: 0.8406 - val_loss: 0.5478 - val_categorical_accuracy: 0.9644 - val_background_recall: 0.9739 - val_background_precision: 0.9967 - val_interior_recall: 0.9663 - val_interior_precision: 0.9524 - val_boundary_recall: 0.8106 - val_boundary_precision: 0.6301
# Epoch 6/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0153 - categorical_accuracy: 0.9964 - background_recall: 0.9981 - background_precision: 0.9999 - interior_recall: 0.9813 - interior_precision: 0.9992 - boundary_recall: 0.9928 - boundary_precision: 0.8676 - val_loss: 0.6417 - val_categorical_accuracy: 0.9692 - val_background_recall: 0.9792 - val_background_precision: 0.9969 - val_interior_recall: 0.9711 - val_interior_precision: 0.9468 - val_boundary_recall: 0.7923 - val_boundary_precision: 0.6538
# Epoch 7/15
# 500/500 [==============================] - 154s 309ms/step - loss: 0.0129 - categorical_accuracy: 0.9969 - background_recall: 0.9984 - background_precision: 0.9999 - interior_recall: 0.9846 - interior_precision: 0.9993 - boundary_recall: 0.9939 - boundary_precision: 0.8869 - val_loss: 0.5844 - val_categorical_accuracy: 0.9663 - val_background_recall: 0.9774 - val_background_precision: 0.9961 - val_interior_recall: 0.9618 - val_interior_precision: 0.9514 - val_boundary_recall: 0.8118 - val_boundary_precision: 0.6421
# Epoch 8/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0107 - categorical_accuracy: 0.9974 - background_recall: 0.9986 - background_precision: 0.9999 - interior_recall: 0.9871 - interior_precision: 0.9994 - boundary_recall: 0.9949 - boundary_precision: 0.9037 - val_loss: 0.5568 - val_categorical_accuracy: 0.9732 - val_background_recall: 0.9825 - val_background_precision: 0.9973 - val_interior_recall: 0.9694 - val_interior_precision: 0.9509 - val_boundary_recall: 0.8083 - val_boundary_precision: 0.6665
# Epoch 9/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0093 - categorical_accuracy: 0.9978 - background_recall: 0.9988 - background_precision: 0.9999 - interior_recall: 0.9890 - interior_precision: 0.9995 - boundary_recall: 0.9956 - boundary_precision: 0.9166 - val_loss: 0.7387 - val_categorical_accuracy: 0.9708 - val_background_recall: 0.9817 - val_background_precision: 0.9965 - val_interior_recall: 0.9733 - val_interior_precision: 0.9547 - val_boundary_recall: 0.7923 - val_boundary_precision: 0.6786
# Epoch 10/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0081 - categorical_accuracy: 0.9981 - background_recall: 0.9990 - background_precision: 0.9999 - interior_recall: 0.9904 - interior_precision: 0.9996 - boundary_recall: 0.9961 - boundary_precision: 0.9265 - val_loss: 0.8606 - val_categorical_accuracy: 0.9670 - val_background_recall: 0.9784 - val_background_precision: 0.9961 - val_interior_recall: 0.9711 - val_interior_precision: 0.9444 - val_boundary_recall: 0.7717 - val_boundary_precision: 0.6562
# Epoch 11/15
# 500/500 [==============================] - 155s 309ms/step - loss: 0.0071 - categorical_accuracy: 0.9983 - background_recall: 0.9991 - background_precision: 0.9999 - interior_recall: 0.9916 - interior_precision: 0.9996 - boundary_recall: 0.9965 - boundary_precision: 0.9346 - val_loss: 0.8646 - val_categorical_accuracy: 0.9695 - val_background_recall: 0.9806 - val_background_precision: 0.9962 - val_interior_recall: 0.9700 - val_interior_precision: 0.9453 - val_boundary_recall: 0.7761 - val_boundary_precision: 0.6679
# Epoch 12/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0063 - categorical_accuracy: 0.9985 - background_recall: 0.9992 - background_precision: 1.0000 - interior_recall: 0.9926 - interior_precision: 0.9997 - boundary_recall: 0.9969 - boundary_precision: 0.9422 - val_loss: 0.8863 - val_categorical_accuracy: 0.9721 - val_background_recall: 0.9825 - val_background_precision: 0.9965 - val_interior_recall: 0.9740 - val_interior_precision: 0.9486 - val_boundary_recall: 0.7848 - val_boundary_precision: 0.6906
# Epoch 13/15
# 500/500 [==============================] - 154s 308ms/step - loss: 0.0056 - categorical_accuracy: 0.9987 - background_recall: 0.9993 - background_precision: 1.0000 - interior_recall: 0.9934 - interior_precision: 0.9997 - boundary_recall: 0.9972 - boundary_precision: 0.9482 - val_loss: 0.7856 - val_categorical_accuracy: 0.9728 - val_background_recall: 0.9839 - val_background_precision: 0.9963 - val_interior_recall: 0.9692 - val_interior_precision: 0.9567 - val_boundary_recall: 0.7924 - val_boundary_precision: 0.6821
# Epoch 14/15
png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 99]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_I08_s2_w11996D679-5D76-4FB8-A681-2014A8999EC8.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 95]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_I11_s6_w1B2DC04C7-2D7D-45C6-9DC2-66D8605FBE63.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 65]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_I16_s9_w1582FD22A-5270-4FDC-868F-5F75808E2321.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 105]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_I18_s3_w1544C8B7A-E092-4F9D-B8D3-C489638D770F.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 131]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_J02_s8_w1D9C198F9-ECF0-4EF7-848D-AC7782CD3C28.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 99]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_J08_s2_w1C146DB1C-05B3-49EF-9C62-1185FD9897AC.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 145]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_J20_s1_w1EEE65E52-7AD8-47C7-A286-6E84C5D77953.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 124]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_K12_s1_w193D6C057-1AA9-4E2F-86EA-2E71961BE68B.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 76]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_K12_s7_w12A7857A5-3C92-4A08-8E81-2CA8A99F67AE.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 174]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_L03_s2_w1AC4550E2-F824-4A58-9CC5-952AD9ECE76A.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 111]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_L05_s2_w1B9C6FAC9-9D48-4184-8D9B-ABFC3BEC1125.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 129]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_L11_s4_w13C057BB5-9CFB-471F-84B5-72F80654CF81.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 145]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_L14_s5_w14B42C89E-7650-44AC-9D7B-50BE61EA307E.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 133]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_M20_s3_w15C73A7C7-F81B-4583-AB8F-0A64336AF070.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 53]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_M23_s8_w118BC311D-A998-4161-8256-22839B2421F2.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 143]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_N12_s7_w166EF3FAB-EA33-4B28-91E3-034A1654BAAE.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 162]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_N18_s2_w1CC5ED51D-86C5-437D-8EDD-E56E4C949B3B.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 111]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_O09_s2_w133C7EDCE-1C7C-41A6-9E52-7AD499E7CDC8.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 70]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_O10_s8_w18F4DB020-BFB7-4F13-B99C-C39F8E54F85D.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 18]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_O13_s3_w12D9C1C9C-C582-4080-B9BE-4807FA3E0843.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 23]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_O16_s2_w1F6F6A3A1-99E4-4029-B734-022806CF6D42.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 114]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_P01_s3_w1A7DC2612-9C11-4656-B100-102AF8FE8B43.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 60]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_P15_s3_w10F5E9699-743C-4177-93CE-27CFD65A925E.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 94]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/morphology/misc.py:212: UserWarning: the min_size argument is deprecated and will be removed in 0.16. Use area_threshold instead.
#   "0.16. Use area_threshold instead.")
# /home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/io/_io.py:141: UserWarning: data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size/out/segm/IXMtest_P21_s5_w1ACEBEE91-BAFA-49E6-9D97-D07197400A15.png is a low contrast image
#   warn('%s is a low contrast image' % fname)
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 94]. Convert image to uint8 prior to saving to suppress this warning.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e3e4ff436d31> in <module>()
#      14
#      15         # Run experiment
# ---> 16         output = utils.experiment.run(config_vars, data_partitions, experiment_name, partition, GPU="2")
#      17
#      18         # Collect outputs
#
# ~/Instance/unet4nuclei/unet4nuclei/utils/experiment.py in run(config_vars, data_partitions, experiment_name, partition, GPU)
#     169         prediction = skimage.segmentation.relabel_sequential(prediction[30:-30,30:-30])[0] # )[0] #
#     170
# --> 171         results = utils.evaluation.compute_ap_results(
#     172             ground_truth,
#     173             prediction,
#
# AttributeError: module 'utils.evaluation' has no attribute 'compute_ap_results'

# %%
results = pd.read_csv("/data1/image-segmentation/BBBC022/unet/experiments/impact_of_augmented_dataset_size.csv")
mean = results.groupby("Samples").mean().reset_index()
sem = results.groupby("Samples").sem().reset_index()
sem.columns = [c+"_se" for c in sem.columns]
data = pd.concat([mean, sem], axis=1).drop(["Samples_se", "Repeat", "Repeat_se"], axis=1)
data

# %%
plt.figure(figsize=(8,8))
plt.errorbar(x=data["Samples"], y=data["Missed"], yerr=data["Missed_se"])
plt.xscale("log")
