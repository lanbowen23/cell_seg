# %% [markdown]
# # Step 03
# # Predict segmentations

# %%
# %matplotlib inline

# %%
import os
import os.path

import matplotlib.pyplot as plt
import numpy as np

import skimage.io
import skimage.morphology

import tensorflow as tf
import keras

import utils.metrics
import utils.model_builder
# Out:
# Using TensorFlow backend.

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2"

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

# %% [markdown]
# # Configuration

# %%
from my_config import config_vars

# Partition of the data to make predictions (test or validation)
partition = "validation"

experiment_name = '00'

config_vars = utils.dirtools.setup_experiment(config_vars, experiment_name)

data_partitions = utils.dirtools.read_data_partitions(config_vars)

# config_vars

# %%
# Device configuration

# Use the following configuration if you want to test on CPUs
# os.environ['CUDA_VISIBLE_DEVICES'] = ''
# configuration = tf.ConfigProto(
#       intra_op_parallelism_threads=1,
#       inter_op_parallelism_threads=1)

# Configuration to run on GPU
configuration = tf.ConfigProto()
configuration.gpu_options.allow_growth = True
configuration.gpu_options.visible_device_list = "0, 1, 2"

session = tf.Session(config = configuration)

# apply session
keras.backend.set_session(session)

# %% [markdown]
# # Load images and run predictions

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#image_names = [f for f in data_partitions[partition] if f.startswith("IXM")]
image_names = [os.path.join(config_vars["normalized_images_dir"], f) for f in data_partitions[partition]]

imagebuffer = skimage.io.imread_collection(image_names)

images = imagebuffer.concatenate()

dim1 = images.shape[1]
dim2 = images.shape[2]

images = images.reshape((-1, dim1, dim2, 1))

# preprocess (assuming images are encoded as 8-bits in the preprocessing step)
images = images / 255

# build model and load weights
model = utils.model_builder.get_model_3_class(dim1, dim2)
model.load_weights(config_vars["model_file"])

# Normal prediction time
predictions = model.predict(images, batch_size=1)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 64) 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512, 512, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 128 147584      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 256, 256, 128 512         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 128 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 256 295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 256 1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 256 590080      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 256 1024        conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 512)  2359808     batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 512)  2048        conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 128, 128, 512 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 768 0           up_sampling2d_1[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 256 1769728     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 256 1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 256 590080      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 256 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 256, 256 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 384 0           up_sampling2d_2[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 128 442496      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 128 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 128 147584      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 128 512         conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 512, 512, 128 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 192 0           up_sampling2d_3[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 512, 512, 64) 110656      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 512, 512, 64) 256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 512, 512, 64) 36928       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 512, 512, 64) 256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 512, 512, 3)  195         batch_normalization_14[0][0]
# ==================================================================================================
# Total params: 7,793,155
# Trainable params: 7,787,523
# Non-trainable params: 5,632
# __________________________________________________________________________________________________

# %% [markdown]
# # Transform predictions to label matrices

# %%
for i in range(len(images)):

    filename = imagebuffer.files[i]
    filename = os.path.basename(filename)
    print(filename)
    
    probmap = predictions[i].squeeze()
    
    skimage.io.imsave(config_vars["probmap_out_dir"] + filename, probmap)
    
    pred = utils.metrics.probmap_to_pred(probmap, config_vars["boundary_boost_factor"])
    
    label = utils.metrics.pred_to_label(pred, config_vars["cell_min_size"])
    
    skimage.io.imsave(config_vars["labels_out_dir"] + filename, label)
    
    if (i < 5):
        plt.imshow(probmap)
        plt.show()
        plt.imshow(pred)
        plt.show()
        plt.imshow(label)
        plt.show()
# Out:
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.582184791564941]. Convert image to uint8 prior to saving to suppress this warning.
# 0000.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 66]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.844900131225586]. Convert image to uint8 prior to saving to suppress this warning.
# 0001.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 66]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.786223411560059]. Convert image to uint8 prior to saving to suppress this warning.
# 0002.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 94]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.262810707092285]. Convert image to uint8 prior to saving to suppress this warning.
# 0003.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 83]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.375999450683594]. Convert image to uint8 prior to saving to suppress this warning.
# 0004.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 107]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.963308334350586]. Convert image to uint8 prior to saving to suppress this warning.
# 0005.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 62]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.878464698791504]. Convert image to uint8 prior to saving to suppress this warning.
# 0006.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 94]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.414876937866211]. Convert image to uint8 prior to saving to suppress this warning.
# 0007.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 77]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.725907325744629]. Convert image to uint8 prior to saving to suppress this warning.
# 0008.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 76]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.810070991516113]. Convert image to uint8 prior to saving to suppress this warning.
# 0009.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 87]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.459637641906738]. Convert image to uint8 prior to saving to suppress this warning.
# 0010.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 104]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.950528144836426]. Convert image to uint8 prior to saving to suppress this warning.
# 0011.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 65]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.803153038024902]. Convert image to uint8 prior to saving to suppress this warning.
# 0012.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 75]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 14.194228172302246]. Convert image to uint8 prior to saving to suppress this warning.
# 0013.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 77]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.97402572631836]. Convert image to uint8 prior to saving to suppress this warning.
# 0014.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 71]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.687575340270996]. Convert image to uint8 prior to saving to suppress this warning.
# 0015.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 67]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.33561897277832]. Convert image to uint8 prior to saving to suppress this warning.
# 0016.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 80]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.472189903259277]. Convert image to uint8 prior to saving to suppress this warning.
# 0017.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 87]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.798028945922852]. Convert image to uint8 prior to saving to suppress this warning.
# 0018.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 100]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.616092681884766]. Convert image to uint8 prior to saving to suppress this warning.
# 0019.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 83]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.472162246704102]. Convert image to uint8 prior to saving to suppress this warning.
# 0020.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 72]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.741850852966309]. Convert image to uint8 prior to saving to suppress this warning.
# 0021.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 96]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.83301830291748]. Convert image to uint8 prior to saving to suppress this warning.
# 0022.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 103]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.79456901550293]. Convert image to uint8 prior to saving to suppress this warning.
# 0023.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 112]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 14.01570987701416]. Convert image to uint8 prior to saving to suppress this warning.
# 0024.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 133]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.971536636352539]. Convert image to uint8 prior to saving to suppress this warning.
# 0025.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 92]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.407485961914062]. Convert image to uint8 prior to saving to suppress this warning.
# 0026.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 95]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.915227890014648]. Convert image to uint8 prior to saving to suppress this warning.
# 0027.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 83]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.830371856689453]. Convert image to uint8 prior to saving to suppress this warning.
# 0028.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 79]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.05671501159668]. Convert image to uint8 prior to saving to suppress this warning.
# 0029.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 130]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.760566711425781]. Convert image to uint8 prior to saving to suppress this warning.
# 0030.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 117]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.822568893432617]. Convert image to uint8 prior to saving to suppress this warning.
# 0031.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 124]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.560091018676758]. Convert image to uint8 prior to saving to suppress this warning.
# 0032.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 74]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.511435508728027]. Convert image to uint8 prior to saving to suppress this warning.
# 0033.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 120]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.92689323425293]. Convert image to uint8 prior to saving to suppress this warning.
# 0034.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 63]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.620546340942383]. Convert image to uint8 prior to saving to suppress this warning.
# 0035.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 60]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.683472633361816]. Convert image to uint8 prior to saving to suppress this warning.
# 0036.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 58]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 14.260446548461914]. Convert image to uint8 prior to saving to suppress this warning.
# 0037.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 54]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.705812454223633]. Convert image to uint8 prior to saving to suppress this warning.
# 0038.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 65]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 14.305148124694824]. Convert image to uint8 prior to saving to suppress this warning.
# 0039.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 60]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.145159721374512]. Convert image to uint8 prior to saving to suppress this warning.
# 0040.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 90]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.041526794433594]. Convert image to uint8 prior to saving to suppress this warning.
# 0041.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 98]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.512872695922852]. Convert image to uint8 prior to saving to suppress this warning.
# 0042.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 70]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.433159828186035]. Convert image to uint8 prior to saving to suppress this warning.
# 0043.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 71]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.231319427490234]. Convert image to uint8 prior to saving to suppress this warning.
# 0044.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 63]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.132058143615723]. Convert image to uint8 prior to saving to suppress this warning.
# 0045.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 59]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 13.237677574157715]. Convert image to uint8 prior to saving to suppress this warning.
# 0046.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 63]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float32 to uint8. Range [0.0, 12.481515884399414]. Convert image to uint8 prior to saving to suppress this warning.
# 0047.png
# WARNING:root:Lossy conversion from int64 to uint8. Range [0, 82]. Convert image to uint8 prior to saving to suppress this warning.
