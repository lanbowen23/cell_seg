# %% [markdown]
# # Step 01
# # Preprocessing input images and annotations

# %%
# %matplotlib inline

# %% [markdown]
# install -U scikit-image

# %%
import os
import random

import matplotlib.pyplot as plt
import numpy as np

import pathlib
from tqdm import tqdm

import skimage.io
import skimage.segmentation

import utils.dirtools
import utils.augmentation
from config import config_vars

# %% [markdown]
# # Configuration

# %%
config_vars
# Out:
# {'root_directory': 'data1/image-segmentation/BBBC022/unet/',
#  'max_training_images': 0,
#  'create_split_files': False,
#  'training_fraction': 0.5,
#  'validation_fraction': 0.25,
#  'transform_images_to_PNG': True,
#  'pixel_depth': 8,
#  'min_nucleus_size': 25,
#  'boundary_size': 2,
#  'augment_images': False,
#  'elastic_points': 16,
#  'elastic_distortion': 5,
#  'elastic_augmentations': 10,
#  'learning_rate': 0.0001,
#  'epochs': 15,
#  'steps_per_epoch': 500,
#  'batch_size': 10,
#  'val_batch_size': 10,
#  'rescale_labels': True,
#  'crop_size': 256,
#  'cell_min_size': 16,
#  'boundary_boost_factor': 1,
#  'object_dilation': 3,
#  'raw_images_dir': 'data1/image-segmentation/BBBC022/unet/raw_images/',
#  'raw_annotations_dir': 'data1/image-segmentation/BBBC022/unet/raw_annotations/',
#  'path_files_training': 'data1/image-segmentation/BBBC022/unet/training.txt',
#  'path_files_validation': 'data1/image-segmentation/BBBC022/unet/validation.txt',
#  'path_files_test': 'data1/image-segmentation/BBBC022/unet/test.txt',
#  'normalized_images_dir': 'data1/image-segmentation/BBBC022/unet/norm_images/',
#  'boundary_labels_dir': 'data1/image-segmentation/BBBC022/unet/boundary_labels/'}

# %% [markdown]
# # Data partitions

# %%
# Prepare split files

if config_vars["create_split_files"]:
    file_list = os.listdir(config_vars["raw_images_dir"])

    [list_training, list_test, list_validation] = utils.dirtools.create_image_lists(
        config_vars["raw_images_dir"],
        config_vars["training_fraction"],
        config_vars["validation_fraction"]
    )

    utils.dirtools.write_path_files(config_vars["path_files_training"], list_training)
    utils.dirtools.write_path_files(config_vars["path_files_test"], list_test)
    utils.dirtools.write_path_files(config_vars["path_files_validation"], list_validation)
    
data_partitions = utils.dirtools.read_data_partitions(config_vars, load_augmented=False)

# %%
# Create output directories for transformed data

os.makedirs(config_vars["normalized_images_dir"], exist_ok=True)
os.makedirs(config_vars["boundary_labels_dir"], exist_ok=True)

# %% [markdown]
# # Image Preprocessing

# %%
if config_vars["transform_images_to_PNG"]:
    
    filelist = sorted(os.listdir(config_vars["raw_images_dir"]))

    # run over all raw images
    for filename in tqdm(filelist):

        # load image and its annotation
        orig_img = skimage.io.imread(config_vars["raw_images_dir"] + filename)       

        # IMAGE

        # normalize to [0,1]
        percentile = 99.9
        high = np.percentile(orig_img, percentile)  # maximum for all image
        low = np.percentile(orig_img, 100-percentile)

        img = np.minimum(high, orig_img)
        img = np.maximum(low, img)

        # gives float64, thus cast to 8 bit later
        img = (img - low) / (high - low) 
        img = skimage.img_as_ubyte(img) 

        skimage.io.imsave(config_vars["normalized_images_dir"] + filename[:-3] + 'png', img)    
else:
    config_vars["normalized_images_dir"] = config_vars["raw_images_dir"]
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]/home/lanbowen23/anaconda3/lib/python3.6/site-packages/skimage/util/dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# 100%|██████████| 200/200 [00:34<00:00,  5.01it/s]

# %%
print(img.dtype, img.shape)
filename = os.listdir(config_vars["normalized_images_dir"])
img = skimage.io.imread(config_vars["normalized_images_dir"] + filename[-1])
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.show()
plt.hist(img.flatten(), bins=100)
plt.show()
# Out:
# uint8 (520, 696)

# %% [markdown]
# # Create Output Targets: Three Class Boundary

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
filelist = sorted(os.listdir(config_vars["raw_annotations_dir"]))
total_objects = 0

# run over all raw images
for filename in tqdm(filelist):
    
    # GET ANNOTATION
    annot = skimage.io.imread(config_vars["raw_annotations_dir"] + filename)
    
    # strip the first channel
    if len(annot.shape) == 3:
        annot = annot[:,:,0]
    
    # label the annotations nicely to prepare for future filtering operation
    annot = skimage.morphology.label(annot)
    total_objects += len(np.unique(annot)) - 1
    
    # filter small objects, e.g. micronulcei
    annot = skimage.morphology.remove_small_objects(annot, min_size=config_vars["min_nucleus_size"])
    
    # find boundaries
    boundaries = skimage.segmentation.find_boundaries(annot)

    for k in range(2, config_vars["boundary_size"], 2):
        boundaries = skimage.morphology.binary_dilation(boundaries)
        
    # BINARY LABEL
    
    # prepare buffer for binary label
    label_binary = np.zeros((annot.shape + (3,)))  # cannot use dtype=np.uint8 here
    
    # write binary label
    label_binary[(annot == 0) & (boundaries == 0), 0] = 1  # bg
    label_binary[(annot != 0) & (boundaries == 0), 1] = 1  # cell
    label_binary[boundaries == 1, 2] = 1  # boundary
    
    # save it - converts image to range from 0 to 255
    skimage.io.imsave(config_vars["boundary_labels_dir"] + filename, label_binary)
    
print("Total objects: ",total_objects)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   0%|          | 1/200 [00:00<00:55,  3.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   1%|          | 2/200 [00:00<00:48,  4.11it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▏         | 3/200 [00:00<00:45,  4.29it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▏         | 4/200 [00:00<00:38,  5.16it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   2%|▎         | 5/200 [00:00<00:36,  5.34it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   3%|▎         | 6/200 [00:01<00:34,  5.65it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▎         | 7/200 [00:01<00:33,  5.79it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▍         | 8/200 [00:01<00:33,  5.82it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   4%|▍         | 9/200 [00:01<00:33,  5.67it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   5%|▌         | 10/200 [00:01<00:31,  6.11it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▌         | 11/200 [00:01<00:30,  6.27it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▌         | 12/200 [00:02<00:28,  6.56it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   6%|▋         | 13/200 [00:02<00:27,  6.80it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   7%|▋         | 14/200 [00:02<00:29,  6.41it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 15/200 [00:02<00:29,  6.30it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 16/200 [00:02<00:30,  5.97it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   8%|▊         | 17/200 [00:02<00:31,  5.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#   9%|▉         | 18/200 [00:03<00:31,  5.85it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|▉         | 19/200 [00:03<00:30,  5.92it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█         | 20/200 [00:03<00:29,  6.08it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  10%|█         | 21/200 [00:03<00:28,  6.23it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  11%|█         | 22/200 [00:03<00:32,  5.43it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 23/200 [00:03<00:32,  5.43it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▏        | 24/200 [00:04<00:35,  4.93it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  12%|█▎        | 25/200 [00:04<00:34,  5.11it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  13%|█▎        | 26/200 [00:04<00:33,  5.16it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|█▎        | 27/200 [00:04<00:30,  5.63it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|█▍        | 28/200 [00:04<00:26,  6.42it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  14%|█▍        | 29/200 [00:04<00:25,  6.65it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  15%|█▌        | 30/200 [00:05<00:28,  6.04it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|█▌        | 31/200 [00:05<00:28,  5.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|█▌        | 32/200 [00:05<00:29,  5.74it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  16%|█▋        | 33/200 [00:05<00:28,  5.77it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  17%|█▋        | 34/200 [00:05<00:28,  5.74it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|█▊        | 35/200 [00:06<00:29,  5.58it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|█▊        | 36/200 [00:06<00:29,  5.56it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  18%|█▊        | 37/200 [00:06<00:28,  5.75it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  19%|█▉        | 38/200 [00:06<00:30,  5.32it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|█▉        | 39/200 [00:06<00:29,  5.51it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|██        | 40/200 [00:06<00:28,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  20%|██        | 41/200 [00:07<00:27,  5.73it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  21%|██        | 42/200 [00:07<00:27,  5.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██▏       | 43/200 [00:07<00:27,  5.67it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██▏       | 44/200 [00:07<00:27,  5.75it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  22%|██▎       | 45/200 [00:07<00:23,  6.52it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  23%|██▎       | 46/200 [00:07<00:25,  6.16it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██▎       | 47/200 [00:08<00:25,  5.94it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██▍       | 48/200 [00:08<00:26,  5.77it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  24%|██▍       | 49/200 [00:08<00:26,  5.65it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  25%|██▌       | 50/200 [00:08<00:26,  5.74it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|██▌       | 51/200 [00:08<00:26,  5.67it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|██▌       | 52/200 [00:08<00:22,  6.45it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  26%|██▋       | 53/200 [00:09<00:24,  6.12it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  27%|██▋       | 54/200 [00:09<00:24,  5.95it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|██▊       | 55/200 [00:09<00:24,  5.93it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|██▊       | 56/200 [00:09<00:24,  5.82it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  28%|██▊       | 57/200 [00:09<00:24,  5.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  29%|██▉       | 58/200 [00:09<00:24,  5.87it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|██▉       | 59/200 [00:10<00:24,  5.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|███       | 60/200 [00:10<00:23,  5.86it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  30%|███       | 61/200 [00:10<00:23,  5.81it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  31%|███       | 62/200 [00:10<00:23,  5.84it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|███▏      | 63/200 [00:10<00:23,  5.95it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|███▏      | 64/200 [00:11<00:23,  5.73it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  32%|███▎      | 65/200 [00:11<00:21,  6.34it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  33%|███▎      | 66/200 [00:11<00:21,  6.23it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  34%|███▍      | 68/200 [00:11<00:20,  6.45it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  35%|███▌      | 70/200 [00:11<00:19,  6.71it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███▌      | 71/200 [00:12<00:23,  5.59it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███▌      | 72/200 [00:12<00:23,  5.51it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  36%|███▋      | 73/200 [00:12<00:22,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  37%|███▋      | 74/200 [00:12<00:23,  5.32it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|███▊      | 75/200 [00:12<00:24,  5.10it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|███▊      | 76/200 [00:13<00:23,  5.20it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  38%|███▊      | 77/200 [00:13<00:22,  5.45it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  39%|███▉      | 78/200 [00:13<00:22,  5.54it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|███▉      | 79/200 [00:13<00:21,  5.67it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|████      | 80/200 [00:13<00:21,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  40%|████      | 81/200 [00:13<00:19,  6.00it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  41%|████      | 82/200 [00:14<00:19,  5.96it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|████▏     | 83/200 [00:14<00:20,  5.80it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|████▏     | 84/200 [00:14<00:19,  5.96it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  42%|████▎     | 85/200 [00:14<00:20,  5.67it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  43%|████▎     | 86/200 [00:14<00:20,  5.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|████▎     | 87/200 [00:14<00:19,  5.73it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|████▍     | 88/200 [00:15<00:19,  5.73it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  44%|████▍     | 89/200 [00:15<00:18,  6.00it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  45%|████▌     | 90/200 [00:15<00:19,  5.70it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████▌     | 91/200 [00:15<00:19,  5.55it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████▌     | 92/200 [00:15<00:17,  6.05it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  46%|████▋     | 93/200 [00:15<00:18,  5.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  47%|████▋     | 94/200 [00:16<00:18,  5.83it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████▊     | 95/200 [00:16<00:18,  5.66it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████▊     | 96/200 [00:16<00:18,  5.52it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  48%|████▊     | 97/200 [00:16<00:17,  5.94it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  49%|████▉     | 98/200 [00:16<00:17,  5.81it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|████▉     | 99/200 [00:17<00:17,  5.69it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|█████     | 100/200 [00:17<00:17,  5.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  50%|█████     | 101/200 [00:17<00:16,  6.00it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  51%|█████     | 102/200 [00:17<00:17,  5.55it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|█████▏    | 103/200 [00:17<00:19,  5.07it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|█████▏    | 104/200 [00:18<00:20,  4.78it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  52%|█████▎    | 105/200 [00:18<00:20,  4.63it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  53%|█████▎    | 106/200 [00:18<00:19,  4.81it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  54%|█████▎    | 107/200 [00:18<00:19,  4.66it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  54%|█████▍    | 108/200 [00:18<00:20,  4.43it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  55%|█████▍    | 109/200 [00:19<00:21,  4.18it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  55%|█████▌    | 110/200 [00:19<00:20,  4.49it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|█████▌    | 111/200 [00:19<00:18,  4.84it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|█████▌    | 112/200 [00:19<00:17,  5.09it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  56%|█████▋    | 113/200 [00:19<00:16,  5.12it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  57%|█████▊    | 115/200 [00:20<00:15,  5.61it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  58%|█████▊    | 116/200 [00:20<00:14,  5.71it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  58%|█████▊    | 117/200 [00:20<00:14,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  59%|█████▉    | 118/200 [00:20<00:15,  5.28it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|█████▉    | 119/200 [00:20<00:15,  5.30it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|██████    | 120/200 [00:21<00:14,  5.43it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  60%|██████    | 121/200 [00:21<00:14,  5.47it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  61%|██████    | 122/200 [00:21<00:14,  5.47it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|██████▏   | 123/200 [00:21<00:13,  5.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|██████▏   | 124/200 [00:21<00:13,  5.84it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  62%|██████▎   | 125/200 [00:22<00:14,  5.20it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  63%|██████▎   | 126/200 [00:22<00:15,  4.82it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|██████▎   | 127/200 [00:22<00:14,  4.99it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|██████▍   | 128/200 [00:22<00:13,  5.41it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  64%|██████▍   | 129/200 [00:22<00:13,  5.36it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  65%|██████▌   | 130/200 [00:23<00:13,  5.01it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|██████▌   | 131/200 [00:23<00:14,  4.80it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|██████▌   | 132/200 [00:23<00:13,  5.08it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  66%|██████▋   | 133/200 [00:23<00:13,  5.06it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  67%|██████▋   | 134/200 [00:23<00:13,  4.81it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|██████▊   | 135/200 [00:24<00:13,  4.95it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|██████▊   | 136/200 [00:24<00:13,  4.84it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  68%|██████▊   | 137/200 [00:24<00:12,  5.00it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  69%|██████▉   | 138/200 [00:24<00:11,  5.23it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  70%|███████   | 140/200 [00:24<00:09,  6.14it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  70%|███████   | 141/200 [00:24<00:09,  6.01it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  71%|███████   | 142/200 [00:25<00:09,  5.95it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|███████▏  | 143/200 [00:25<00:09,  5.85it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|███████▏  | 144/200 [00:25<00:09,  6.09it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  72%|███████▎  | 145/200 [00:25<00:09,  5.92it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▎  | 147/200 [00:25<00:08,  6.37it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▍  | 148/200 [00:26<00:09,  5.43it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  74%|███████▍  | 149/200 [00:26<00:09,  5.11it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  75%|███████▌  | 150/200 [00:26<00:10,  4.96it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▌  | 151/200 [00:26<00:09,  4.90it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▌  | 152/200 [00:27<00:10,  4.77it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  76%|███████▋  | 153/200 [00:27<00:09,  5.01it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  77%|███████▋  | 154/200 [00:27<00:08,  5.15it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 155/200 [00:27<00:08,  5.35it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 156/200 [00:27<00:07,  5.79it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  78%|███████▊  | 157/200 [00:27<00:08,  5.03it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  79%|███████▉  | 158/200 [00:28<00:08,  5.02it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|███████▉  | 159/200 [00:28<00:07,  5.26it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████  | 160/200 [00:28<00:07,  5.42it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  80%|████████  | 161/200 [00:28<00:06,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  81%|████████  | 162/200 [00:28<00:06,  5.49it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▏ | 163/200 [00:29<00:07,  4.88it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▏ | 164/200 [00:29<00:06,  5.19it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  82%|████████▎ | 165/200 [00:29<00:06,  5.49it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  83%|████████▎ | 166/200 [00:29<00:06,  5.59it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|████████▎ | 167/200 [00:29<00:05,  5.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  84%|████████▍ | 169/200 [00:30<00:04,  6.21it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  85%|████████▌ | 170/200 [00:30<00:04,  6.48it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▌ | 171/200 [00:30<00:04,  6.68it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▌ | 172/200 [00:30<00:04,  6.81it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  86%|████████▋ | 173/200 [00:30<00:04,  6.72it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  87%|████████▋ | 174/200 [00:30<00:03,  6.66it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|████████▊ | 175/200 [00:30<00:03,  6.66it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  88%|████████▊ | 176/200 [00:31<00:03,  6.69it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  89%|████████▉ | 178/200 [00:31<00:02,  7.56it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|████████▉ | 179/200 [00:31<00:02,  7.83it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|█████████ | 180/200 [00:31<00:03,  6.58it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  90%|█████████ | 181/200 [00:31<00:03,  6.30it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  91%|█████████ | 182/200 [00:31<00:02,  6.04it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▏| 183/200 [00:32<00:02,  5.97it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▏| 184/200 [00:32<00:02,  5.52it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  92%|█████████▎| 185/200 [00:32<00:02,  5.51it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  93%|█████████▎| 186/200 [00:32<00:02,  4.96it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████▎| 187/200 [00:32<00:02,  4.87it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████▍| 188/200 [00:33<00:02,  5.19it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  94%|█████████▍| 189/200 [00:33<00:01,  5.94it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  95%|█████████▌| 190/200 [00:33<00:01,  5.52it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▌| 191/200 [00:33<00:01,  5.60it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▌| 192/200 [00:33<00:01,  5.89it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  96%|█████████▋| 193/200 [00:33<00:01,  6.08it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  97%|█████████▋| 194/200 [00:34<00:00,  6.37it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 195/200 [00:34<00:00,  6.34it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 196/200 [00:34<00:00,  6.79it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
#  98%|█████████▊| 197/200 [00:34<00:00,  6.61it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|█████████▉| 199/200 [00:34<00:00,  7.01it/s]WARNING:root:Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# 100%|██████████| 200/200 [00:34<00:00,  6.93it/s]
# Total objects:  23615

# %%
# Show example image 
print(annot.dtype, annot.shape)

# plot original annotation
plt.figure(figsize=(10,10))
plt.imshow(annot, cmap="nipy_spectral")
plt.show()

# plot boundary labels
plt.figure(figsize=(10,10))
plt.imshow(label_binary)
plt.show()
# Out:
# int64 (520, 696)

# %% [markdown]
# # Augment images (optional)
# * data augmentation using affine transformations
# * n_points x n_points data points are equally distributed in the image
# * distort
# * n_augmentations images are calculated for each image

# %%
def generate_augmented_examples(filelist, n_augmentations, n_points, distort, dir_boundary_labels, dir_images_normalized_8bit):
    
    updated_filelist = []
    
    # run over all raw images
    for filename in tqdm(filelist):
        
        #if filename.startswith("IXMtest"):
        #    print("Skipping", filename)
        #    continue
            
        # check if boundary labels were calculated 
        my_file = pathlib.Path(dir_boundary_labels + filename)
        
        if my_file.is_file():
            
            # load image 
            x = skimage.io.imread(dir_images_normalized_8bit + filename)
            
            # load annotation 
            y = skimage.io.imread(dir_boundary_labels + filename)
            
            for n in range(1,n_augmentations):
                # augment image and annotation 
                x_augmented, y_augmented = utils.augmentation.deform(x, y, points = n_points, distort = distort)
                
                # filename for augmented images
                filename_augmented = os.path.splitext(filename)[0] + '_aug_{:03d}'.format(n) + os.path.splitext(filename)[1]
                skimage.io.imsave(dir_images_normalized_8bit + filename_augmented, x)
                skimage.io.imsave(dir_boundary_labels + filename_augmented, y)
                updated_filelist.append(filename_augmented)
                
    return filelist + updated_filelist 

if config_vars["augment_images"]:
    
    tmp_value = config_vars["max_training_images"]
    config_vars["max_training_images"] = 0
    tmp_partitions = utils.dirtools.read_data_partitions(config_vars, load_augmented=False)
    
    training_files = generate_augmented_examples(
        tmp_partitions["training"], 
        config_vars["elastic_augmentations"], 
        config_vars["elastic_points"], 
        config_vars["elastic_distortion"], 
        config_vars["boundary_labels_dir"], 
        config_vars["normalized_images_dir"]
    )
    
    config_vars["max_training_images"] = tmp_value
